# %%
import os
import pandas as pd
import numpy as np
import sys
import csv
from time import strptime
import json
from datetime import datetime as dt
from datetime import date
from statistics import mean
import math
import pickle
import time

# %%
# csv.field_size_limit(sys.maxsize)
# np.set_printoptions(threshold=sys.maxsize)
pd.options.display.max_columns = None
pd.options.display.float_format = '{:20,.15f}'.format
# pd.options.display.max_rows = 10000
# pd.set_option('display.max_colwidth', -1)

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
def calc_smooth_mean(df, by, on, m):
    mean = df[on].mean()
    agg = df.groupby(by)[on].agg(['count', 'mean'])
    counts = agg['count']
    means = agg['mean']
    smooth = (counts * means + m * mean) / (counts + m)
    return df[by].map(smooth)

# %%
df_file = pd.read_csv('savedcsv/17_homepage.csv')
df_file = df_file.drop(df_file[df_file['META__id'] == 6].index)
df_file.to_csv('datasets/df_file.csv', index=False)
df_file = pd.read_csv('datasets/df_file.csv')

# %%
# df_raw = reduce_mem_usage(pd.read_csv('savedcsv/17_homepage.csv'))
df_raw = pd.read_csv('savedcsv/17_homepage.csv')
df_raw['META__profitability'] = df_raw['profitability']
df_raw['META__year_avg_profitability'] = df_raw['year_avg_profitability']
df_raw = df_raw.drop(['profitability', 'year_avg_profitability', 'PROCESS__original_language'], axis=1)
drop_cols = [c for c in df_raw.columns if 'META' not in c and ('avg' in c or 'experience' in c or 'movies_before' in c)]
df_raw = df_raw.drop(drop_cols, axis=1)
df_raw = df_raw.drop(df_raw[df_raw['META__id'] == 6].index)
df_raw.to_csv('datasets/df_raw.csv', index=False)
df_raw = pd.read_csv('datasets/df_raw.csv')

# %%
df_raw = pd.read_csv('datasets/df_raw.csv')

# %%
df_raw.META__revenue.quantile([0.05, 0.95])
# Out:
# 0.050000000000000       111,229.200000000011642
# 0.950000000000000   348,514,752.599999785423279
# Name: META__revenue, dtype: float64

# %%
num = df_raw[
    (df_raw.META__profitability > df_raw.META__profitability.quantile(0.01)) & 
    (df_raw.META__profitability < df_raw.META__profitability.quantile(0.99)) &
    (df_raw.META__year >= 2000) &
    (df_raw.META__year <= 2018) &
    (df_raw.budget >= 250000)
].shape[0]

print(num)
print(num/df_raw.shape[0])

# %%
num = df_raw[
    (df_raw.META__revenue > df_raw.META__profitability.quantile(0.01)) & 
    (df_raw.META__profitability < df_raw.META__profitability.quantile(0.99)) &
    (df_raw.META__year >= 2000) &
    (df_raw.META__year <= 2018) &
    (df_raw.budget >= 250000)
].shape[0]

print(num)
print(num/df_raw.shape[0])

# %%
def get_real_columns(name_prefix, name_suffix, num_columns):
    return [f'{name_prefix}{j}{name_suffix}' for j in range(1, num_columns+1)]

def get_date_from_movie(movie):
    return date(movie['META__year'], movie['META__month'], movie['META__day'])


def get_info_df_movies_per_value_range_columns(df, columns):
    result = {}
    for i, row in df.iterrows():
        for col in columns:
            value = row[col]
            if not pd.isna(value):
                if value in list(result.keys()):
                    result[value]['movies'] = result[value]['movies'].append(df.iloc[[i]])
                else:
                    result[value] = {'movies': df.iloc[[i]]}
    return result

# def get_info_df_movies_per_value_range_columns(df, columns):
#     def rows_with_value(value):
#         return df[df.apply(lambda row: value in [row[column] for column in columns], axis=1)]

#     unique_values = list(set([movie[column] for i, movie in df.iterrows() for column in columns]))
#     return {value: rows_with_value(value) for value in unique_values}

def calculate_info_per_previous_movies_per_value(df, 
                                                 info_dict, 
                                                 calc_budget=False, 
                                                 calc_movies_before=False, 
                                                 calc_experience=False, 
                                                 calc_revenue=False,
                                                ):
    
    def get_average_profit(df):
        return (df['META__revenue'] - df['budget']).mean()
    
    def get_experience(df, row):
        return (row['META__year'] - df.META__year.min())
    
    def is_movie_before(movie, compare_date):
        return date(movie.META__year, movie.META__month, movie.META__day) < compare_date

    for value_name in info_dict:
        value = info_dict[value_name]
        value['avg_profit'] = {}
        if calc_budget:
            value['avg_budget'] = {}
        if calc_experience:
            value['experience'] = {}
        if calc_revenue:
            value['avg_revenue'] = {}
        if calc_movies_before:
            value['movies_before'] = {}

        movies = value['movies']
        for movie_index, movie in movies.iterrows():
            current_date = get_date_from_movie(movie)
            str_date = str(current_date)
            if calc_experience and str_date not in list(value['experience'].keys()):
                value['experience'][str_date] = get_experience(movies, movie)
            if str_date not in list(value['avg_profit'].keys()):
                movies_before = movies[movies.apply(lambda row: is_movie_before(row, current_date), axis=1)]
                if not movies_before.empty:
                    value['avg_profit'][str_date] = get_average_profit(movies_before)
                    if calc_movies_before:
                        value['movies_before'][str_date] = movies_before.shape[0]
                    if calc_revenue:
                        value['avg_revenue'][str_date] = movies_before['META__revenue'].mean()                        
                    if calc_budget:
                        value['avg_budget'][str_date] = movies_before['budget'].mean()
                    

def get_columns_from_info_dict(df, info_dict, real_columns, new_column_prefix='', nested_info=False):
    def get_first_key(d):
        return d[list(d.keys())[0]]
    
    new_columns_data = {}
    info_names = [key for key in get_first_key(info_dict).keys() if key != 'movies']
    print(info_names)
    for index, real_column in enumerate(real_columns):
        print(real_column)
        new_column_names = [f'{new_column_prefix}_{key}' if len(real_columns) == 1 else f'{new_column_prefix}_{index+1}_{key}' for key in info_names] 
        print(new_column_names)
            
        for new_column_name in new_column_names:
            new_columns_data[new_column_name] = []

        for movie_index, movie in df.iterrows():
            value = movie[real_column]
            str_date = str(get_date_from_movie(movie))
            if pd.isna(value):
                for col in new_column_names:
                    new_columns_data[col].append(np.nan)
            else:
                for name_index, new_column_name in enumerate(new_column_names):
                    year_info = info_dict[value][info_names[name_index]].get(str_date, np.nan)
                    new_columns_data[new_column_name].append(year_info)
    return new_columns_data

# %%
def add_features(df, 
                 columns,
                 new_column_prefix,
                 calc_movies_before=False, 
                 calc_budget=False, 
                 calc_experience=False,
                 calc_revenue=False):
    print('obtaine movies')
    
    t = time.process_time()
    data_info = get_info_df_movies_per_value_range_columns(df, columns)
    print(f'time: {time.process_time() - t}')
    
    data_info_copy = data_info.copy()
    print('calculate info')
    t = time.process_time()
    calculate_info_per_previous_movies_per_value(df, 
                                                 data_info_copy, 
                                                 calc_movies_before=calc_movies_before, 
                                                 calc_budget=calc_budget, 
                                                 calc_experience=calc_experience,
                                                 calc_revenue=calc_revenue)
    print(f'time: {time.process_time() - t}')
    
    print('get columns')
    t = time.process_time()
    feature_columns = get_columns_from_info_dict(df, data_info_copy, columns, new_column_prefix=new_column_prefix)
    print(f'time: {time.process_time() - t}')
    for column in feature_columns.keys():
        df[column] = feature_columns[column]
    return df


def add_companies_features(df):
    columns = get_real_columns('META__production_company_', '', 3)
    return add_features(df, columns, 'production_company', calc_revenue=True)


def add_cast_features(df):
    columns = get_real_columns('META__cast_', '_name', 8)
    return add_features(df, columns, 'cast', calc_movies_before=True, calc_revenue=True, calc_experience=True)


def add_crew_features(df):
    for column in [c for c in list(df.columns) if 'META__crew' in c]:
        df = add_features(df, [column], column.replace('META__', ''), calc_movies_before=True, calc_revenue=True)
    return df


def add_collection_features(df):
    return add_features(df, ['META__collection_name'], 'collection', calc_revenue=True)


def get_avg_cast_info(df):
    def get_average_cast_movies(row, columns):
        avgs = [row[col] for col in columns if not pd.isna(row[col])]
        return mean(avgs) if len(avgs) else np.nan
    
    def get_cast_average(df, column_name):
        columns = [col for col in df.columns if 'cast_' in col and column_name in col and not 'cast_avg' in col]
        return [get_average_cast_movies(row, columns) for i, row in df.iterrows()]
    
    for column in ['revenue', 'profit', 'experience', 'movies_before']:
        df[f'cast_avg_{column}'] = get_cast_average(df, column)
    return df


def prepare_df(df_original):
    overall_time = time.process_time()
    df = df_original.copy()
    df = add_companies_features(df)
    df = add_cast_features(df)
    df = add_crew_features(df)
    df = add_collection_features(df)
    df = get_avg_cast_info(df)
    df['year_avg_revenue'] = calc_smooth_mean(df, by='META__year', on='META__revenue', m=5)
    print(f'overall time: {time.process_time() - overall_time}')
    return df

# %%
df_all = prepare_df(df_raw)

# %%
raw_datasets = {
#     'us': df_raw[
#         df_raw.country__us == 1].copy(),
#     'gb': df_raw[
#         df_raw.country__gb == 1].copy(),
#     'years2000-2018': df_raw[
#         (df_raw.META__year >= 2000) &
#         (df_raw.META__year <= 2018)].copy(),
#     'years1970-1999': df_raw[
#         (df_raw.META__year >= 1970) &
#         (df_raw.META__year <= 1999)].copy(),
#     'profitability_positive': df_raw[
#         df_raw.META__profitability > 0].copy(),
#     'profitability_negative': df_raw[
#         df_raw.META__profitability < 0].copy(),
#     'budget_start_1percent': df_raw[
#         df_raw.budget >= 8875].copy(),
#     'budget_start_5percent': df_raw[
#         df_raw.budget >= 250000].copy(),
#     'profitability_1percentile': df_raw[
#         (df_raw.META__profitability >= -138) &
#         (df_raw.META__profitability <= 65)].copy(),
#     'profitability_5percentile': df_raw[
#         (df_raw.META__profitability >= -14.9) &
#         (df_raw.META__profitability <= 13.9)].copy(),
#     'profitability_10percentile': df_raw[
#         (df_raw.META__profitability >= -4.42) &
#         (df_raw.META__profitability <= 7.4)].copy(),
#     'profitability_1percentile_years2000-2018': df_raw[
#         (df_raw.META__profitability >= -138) &
#         (df_raw.META__profitability <= 65) &
#         (df_raw.META__year >= 2000) &
#         (df_raw.META__year <= 2018)].copy(),
#     'profitability_1percentile_years2000-2018_budget_start_1percent': df_raw[
#         (df_raw.META__profitability >= -138) &
#         (df_raw.META__profitability <= 65) &
#         (df_raw.META__year >= 2000) &
#         (df_raw.META__year <= 2018) &
#         (df_raw.budget >= 8875)].copy(),
#     'profitability_1percentile_years2000-2018_budget_start_5percent': df_raw[
#         (df_raw.META__profitability >= -138) &
#         (df_raw.META__profitability <= 65) &
#         (df_raw.META__year >= 2000) &
#         (df_raw.META__year <= 2018) &
#         (df_raw.budget >= 250000)].copy(),
    'revenue_1percentile': df_raw[
        (df_raw.META__revenue >= 10000) &
        (df_raw.META__revenue <= 854060072)].copy(),
    'revenue_5percentile': df_raw[
        (df_raw.META__revenue >= 111229) &
        (df_raw.META__revenue <= 348514752)].copy(),
}
# Out:
#   File "<ipython-input-16-78adbb5cbd03>", line 52
#     ]
#     ^
# SyntaxError: invalid syntax

# %%
for d in raw_datasets.keys():
    print(raw_datasets[d].shape[0])
for d in raw_datasets.keys():
    print(raw_datasets[d].shape[0]/df_raw.shape[0]*100)

# %%
for dataset in raw_datasets.keys():
    print('------------------------------------------------------')
    print(dataset)
    print('-------------------------------------------------------')
    raw_filename = f'datasets/dataset_{dataset}_raw.csv'
    filename = f'datasets/dataset_{dataset}.csv'
    raw_datasets[dataset].to_csv(raw_filename, index=False)
    raw_dataset = pd.read_csv(raw_filename)
    prepared = prepare_df(raw_dataset)
    prepared.to_csv(filename, index=False)
# Out:
# ------------------------------------------------------
# us
# -------------------------------------------------------
# obtaine movies
# time: 26.411767158000004
# calculate info
# time: 42.984574178
# get columns
# ['avg_profit', 'avg_revenue']
# META__production_company_1
# ['production_company_1_avg_profit', 'production_company_1_avg_revenue']
# META__production_company_2
# ['production_company_2_avg_profit', 'production_company_2_avg_revenue']
# META__production_company_3
# ['production_company_3_avg_profit', 'production_company_3_avg_revenue']
# time: 1.5053753009999866
# obtaine movies
# time: 86.712821249
# calculate info
# time: 65.733221748
# get columns
# ['avg_profit', 'experience', 'avg_revenue', 'movies_before']
# META__cast_1_name
# ['cast_1_avg_profit', 'cast_1_experience', 'cast_1_avg_revenue', 'cast_1_movies_before']
# META__cast_2_name
# ['cast_2_avg_profit', 'cast_2_experience', 'cast_2_avg_revenue', 'cast_2_movies_before']
# META__cast_3_name
# ['cast_3_avg_profit', 'cast_3_experience', 'cast_3_avg_revenue', 'cast_3_movies_before']
# META__cast_4_name
# ['cast_4_avg_profit', 'cast_4_experience', 'cast_4_avg_revenue', 'cast_4_movies_before']
# META__cast_5_name
# ['cast_5_avg_profit', 'cast_5_experience', 'cast_5_avg_revenue', 'cast_5_movies_before']
# META__cast_6_name
# ['cast_6_avg_profit', 'cast_6_experience', 'cast_6_avg_revenue', 'cast_6_movies_before']
# META__cast_7_name
# ['cast_7_avg_profit', 'cast_7_experience', 'cast_7_avg_revenue', 'cast_7_movies_before']
# META__cast_8_name
# ['cast_8_avg_profit', 'cast_8_experience', 'cast_8_avg_revenue', 'cast_8_movies_before']
# time: 4.089270357999993
# obtaine movies
# time: 3.9795601960000226
# calculate info
# time: 2.226854803000009
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__music_editor
# ['crew__sound__music_editor_avg_profit', 'crew__sound__music_editor_avg_revenue', 'crew__sound__music_editor_movies_before']
# time: 0.5091795289999936
# obtaine movies
# time: 9.813454174000015
# calculate info
# time: 7.142210430000034
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__original_music_composer
# ['crew__sound__original_music_composer_avg_profit', 'crew__sound__original_music_composer_avg_revenue', 'crew__sound__original_music_composer_movies_before']
# time: 0.5255266390000202
# obtaine movies
# time: 2.5946773750000034
# calculate info
# time: 1.5365786720000187
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__sound_designer
# ['crew__sound__sound_designer_avg_profit', 'crew__sound__sound_designer_avg_revenue', 'crew__sound__sound_designer_movies_before']
# time: 0.5076695029999883
# obtaine movies
# time: 2.9484259350000457
# calculate info
# time: 1.7795014259999675
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__sound_effects_editor
# ['crew__sound__sound_effects_editor_avg_profit', 'crew__sound__sound_effects_editor_avg_revenue', 'crew__sound__sound_effects_editor_movies_before']
# time: 0.5132319490000441
# obtaine movies
# time: 4.344296994999979
# calculate info
# time: 2.5358853439999507
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__sound_re_recording_mixer
# ['crew__sound__sound_re_recording_mixer_avg_profit', 'crew__sound__sound_re_recording_mixer_avg_revenue', 'crew__sound__sound_re_recording_mixer_movies_before']
# time: 0.4818761850000328
# obtaine movies
# time: 4.035522649999962
# calculate info
# time: 2.3778836710000064
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__supervising_sound_editor
# ['crew__sound__supervising_sound_editor_avg_profit', 'crew__sound__supervising_sound_editor_avg_revenue', 'crew__sound__supervising_sound_editor_movies_before']
# time: 0.5047275860000013
# obtaine movies
# time: 10.984409701000004
# calculate info
# time: 7.45576196899998
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__directing__director__1
# ['crew__directing__director__1_avg_profit', 'crew__directing__director__1_avg_revenue', 'crew__directing__director__1_movies_before']
# time: 0.5202379520000022
# obtaine movies
# time: 5.261793036000029
# calculate info
# time: 3.161273611000013
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__directing__script_supervisor
# ['crew__directing__script_supervisor_avg_profit', 'crew__directing__script_supervisor_avg_revenue', 'crew__directing__script_supervisor_movies_before']
# time: 0.5202277730000446
# obtaine movies
# time: 10.003088107999986
# calculate info
# time: 7.593990446000021
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__casting
# ['crew__production__casting_avg_profit', 'crew__production__casting_avg_revenue', 'crew__production__casting_movies_before']
# time: 0.518048943999986
# obtaine movies
# time: 5.842786180000019
# calculate info
# time: 5.005524961999981
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__executive_producer__1
# ['crew__production__executive_producer__1_avg_profit', 'crew__production__executive_producer__1_avg_revenue', 'crew__production__executive_producer__1_movies_before']
# time: 0.5160333899999614
# obtaine movies
# time: 10.143163496
# calculate info
# time: 7.163316519999967
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__producer__1
# ['crew__production__producer__1_avg_profit', 'crew__production__producer__1_avg_revenue', 'crew__production__producer__1_movies_before']
# time: 0.5257180400000152
# obtaine movies
# time: 2.900229766999985
# calculate info
# time: 2.748164612000039
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__producer__2
# ['crew__production__producer__2_avg_profit', 'crew__production__producer__2_avg_revenue', 'crew__production__producer__2_movies_before']
# time: 0.5161687749999828
# obtaine movies
# time: 11.199798094000016
# calculate info
# time: 7.030805365000049
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__editing__editor__1
# ['crew__editing__editor__1_avg_profit', 'crew__editing__editor__1_avg_revenue', 'crew__editing__editor__1_movies_before']
# time: 0.5106485449999809
# obtaine movies
# time: 8.657828403999986
# calculate info
# time: 5.530251002
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__costume__costume_designer
# ['crew__costume__costume_designer_avg_profit', 'crew__costume__costume_designer_avg_revenue', 'crew__costume__costume_designer_movies_before']
# time: 0.5206172649999985
# obtaine movies
# time: 2.6474731290000477
# calculate info
# time: 1.7112684680000143
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__costume__costume_supervisor
# ['crew__costume__costume_supervisor_avg_profit', 'crew__costume__costume_supervisor_avg_revenue', 'crew__costume__costume_supervisor_movies_before']
# time: 0.49197796300001073
# obtaine movies
# time: 3.2926776200000063
# calculate info
# time: 2.440061836000041
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__costume__makeup_artist
# ['crew__costume__makeup_artist_avg_profit', 'crew__costume__makeup_artist_avg_revenue', 'crew__costume__makeup_artist_movies_before']
# time: 0.5102101379999908
# obtaine movies
# time: 3.3063017999999715
# calculate info
# time: 2.0324607809999975
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__crew__stunt_coordinator
# ['crew__crew__stunt_coordinator_avg_profit', 'crew__crew__stunt_coordinator_avg_revenue', 'crew__crew__stunt_coordinator_movies_before']
# time: 0.5103977520000171
# obtaine movies
# time: 5.911888395999995
# calculate info
# time: 4.639345554000045
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__writing__screenplay__1
# ['crew__writing__screenplay__1_avg_profit', 'crew__writing__screenplay__1_avg_revenue', 'crew__writing__screenplay__1_movies_before']
# time: 0.5212915259999704
# obtaine movies
# time: 6.051694944000019
# calculate info
# time: 4.123917441000003
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__art_direction
# ['crew__art__art_direction_avg_profit', 'crew__art__art_direction_avg_revenue', 'crew__art__art_direction_movies_before']
# time: 0.49346629600000824
# obtaine movies
# time: 8.945381682999994
# calculate info
# time: 5.503574409999999
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__production_design
# ['crew__art__production_design_avg_profit', 'crew__art__production_design_avg_revenue', 'crew__art__production_design_movies_before']
# time: 0.5112733509999998
# obtaine movies
# time: 3.144172088000005
# calculate info
# time: 1.9264206130000048
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__property_master
# ['crew__art__property_master_avg_profit', 'crew__art__property_master_avg_revenue', 'crew__art__property_master_movies_before']
# time: 0.4970076780000454
# obtaine movies
# time: 6.906914289999975
# calculate info
# time: 4.3607796830000325
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__set_decoration
# ['crew__art__set_decoration_avg_profit', 'crew__art__set_decoration_avg_revenue', 'crew__art__set_decoration_movies_before']
# time: 0.5000797810000108
# obtaine movies
# time: 2.6817989019999686
# calculate info
# time: 1.7981295160000172
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__visualeffects__visual_effects_supervisor
# ['crew__visualeffects__visual_effects_supervisor_avg_profit', 'crew__visualeffects__visual_effects_supervisor_avg_revenue', 'crew__visualeffects__visual_effects_supervisor_movies_before']
# time: 0.49549134900001945
# obtaine movies
# time: 11.331517872999996
# calculate info
# time: 7.046700020000003
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__camera__director_of_photography
# ['crew__camera__director_of_photography_avg_profit', 'crew__camera__director_of_photography_avg_revenue', 'crew__camera__director_of_photography_movies_before']
# time: 0.5018858870000145
# obtaine movies
# time: 2.459596406000003
# calculate info
# time: 1.372623745999988
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__camera__steadicam_operator
# ['crew__camera__steadicam_operator_avg_profit', 'crew__camera__steadicam_operator_avg_revenue', 'crew__camera__steadicam_operator_movies_before']
# time: 0.5037040450000632
# obtaine movies
# time: 4.557494487999975
# calculate info
# time: 2.787723003999986
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__camera__still_photographer
# ['crew__camera__still_photographer_avg_profit', 'crew__camera__still_photographer_avg_revenue', 'crew__camera__still_photographer_movies_before']
# time: 0.49949835400002485
# obtaine movies
# time: 2.195580156999995
# calculate info
# time: 1.27422935900006
# get columns
# ['avg_profit', 'avg_revenue']
# META__collection_name
# ['collection_avg_profit', 'collection_avg_revenue']
# time: 0.4959355130000631
# overall time: 506.08611506499994
# ------------------------------------------------------
# gb
# -------------------------------------------------------
# obtaine movies
# time: 3.3249861909999936
# calculate info
# time: 3.06150814800003
# get columns
# ['avg_profit', 'avg_revenue']
# META__production_company_1
# ['production_company_1_avg_profit', 'production_company_1_avg_revenue']
# META__production_company_2
# ['production_company_2_avg_profit', 'production_company_2_avg_revenue']
# META__production_company_3
# ['production_company_3_avg_profit', 'production_company_3_avg_revenue']
# time: 0.22709519899990482
# obtaine movies
# time: 8.45979403900003
# calculate info
# time: 8.19133043599993
# get columns
# ['avg_profit', 'experience', 'avg_revenue', 'movies_before']
# META__cast_1_name
# ['cast_1_avg_profit', 'cast_1_experience', 'cast_1_avg_revenue', 'cast_1_movies_before']
# META__cast_2_name
# ['cast_2_avg_profit', 'cast_2_experience', 'cast_2_avg_revenue', 'cast_2_movies_before']
# META__cast_3_name
# ['cast_3_avg_profit', 'cast_3_experience', 'cast_3_avg_revenue', 'cast_3_movies_before']
# META__cast_4_name
# ['cast_4_avg_profit', 'cast_4_experience', 'cast_4_avg_revenue', 'cast_4_movies_before']
# META__cast_5_name
# ['cast_5_avg_profit', 'cast_5_experience', 'cast_5_avg_revenue', 'cast_5_movies_before']
# META__cast_6_name
# ['cast_6_avg_profit', 'cast_6_experience', 'cast_6_avg_revenue', 'cast_6_movies_before']
# META__cast_7_name
# ['cast_7_avg_profit', 'cast_7_experience', 'cast_7_avg_revenue', 'cast_7_movies_before']
# META__cast_8_name
# ['cast_8_avg_profit', 'cast_8_experience', 'cast_8_avg_revenue', 'cast_8_movies_before']
# time: 0.5956408240000428
# obtaine movies
# time: 0.438431971
# calculate info
# time: 0.29589909499998157
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__music_editor
# ['crew__sound__music_editor_avg_profit', 'crew__sound__music_editor_avg_revenue', 'crew__sound__music_editor_movies_before']
# time: 0.07314003299995875
# obtaine movies
# time: 1.0360323139999537
# calculate info
# time: 0.7572768229999838
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__original_music_composer
# ['crew__sound__original_music_composer_avg_profit', 'crew__sound__original_music_composer_avg_revenue', 'crew__sound__original_music_composer_movies_before']
# time: 0.07518248400003813
# obtaine movies
# time: 0.27372405599999183
# calculate info
# time: 0.23581419100003131
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__sound_designer
# ['crew__sound__sound_designer_avg_profit', 'crew__sound__sound_designer_avg_revenue', 'crew__sound__sound_designer_movies_before']
# time: 0.07242476500005068
# obtaine movies
# time: 0.24817872799997076
# calculate info
# time: 0.22612223600003745
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__sound_effects_editor
# ['crew__sound__sound_effects_editor_avg_profit', 'crew__sound__sound_effects_editor_avg_revenue', 'crew__sound__sound_effects_editor_movies_before']
# time: 0.07486069000003681
# obtaine movies
# time: 0.48751263899998776
# calculate info
# time: 0.34285498400004144
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__sound_re_recording_mixer
# ['crew__sound__sound_re_recording_mixer_avg_profit', 'crew__sound__sound_re_recording_mixer_avg_revenue', 'crew__sound__sound_re_recording_mixer_movies_before']
# time: 0.0746566120000125
# obtaine movies
# time: 0.46595208899998397
# calculate info
# time: 0.3339932379999482
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__supervising_sound_editor
# ['crew__sound__supervising_sound_editor_avg_profit', 'crew__sound__supervising_sound_editor_avg_revenue', 'crew__sound__supervising_sound_editor_movies_before']
# time: 0.07680035299995325
# obtaine movies
# time: 1.1050542210000458
# calculate info
# time: 1.0064274190000333
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__directing__director__1
# ['crew__directing__director__1_avg_profit', 'crew__directing__director__1_avg_revenue', 'crew__directing__director__1_movies_before']
# time: 0.07540841699994871
# obtaine movies
# time: 0.6100792099999808
# calculate info
# time: 0.45347177500002545
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__directing__script_supervisor
# ['crew__directing__script_supervisor_avg_profit', 'crew__directing__script_supervisor_avg_revenue', 'crew__directing__script_supervisor_movies_before']
# time: 0.07476273200006744
# obtaine movies
# time: 1.3363549530000682
# calculate info
# time: 0.8633981279999716
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__casting
# ['crew__production__casting_avg_profit', 'crew__production__casting_avg_revenue', 'crew__production__casting_movies_before']
# time: 0.07545156800006225
# obtaine movies
# time: 0.6459296689999974
# calculate info
# time: 0.6362450340000123
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__executive_producer__1
# ['crew__production__executive_producer__1_avg_profit', 'crew__production__executive_producer__1_avg_revenue', 'crew__production__executive_producer__1_movies_before']
# time: 0.07556067900009111
# obtaine movies
# time: 1.052152762999981
# calculate info
# time: 0.9991385010000613
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__producer__1
# ['crew__production__producer__1_avg_profit', 'crew__production__producer__1_avg_revenue', 'crew__production__producer__1_movies_before']
# time: 0.07950803699998232
# obtaine movies
# time: 0.32028232000004664
# calculate info
# time: 0.4310327399999778
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__producer__2
# ['crew__production__producer__2_avg_profit', 'crew__production__producer__2_avg_revenue', 'crew__production__producer__2_movies_before']
# time: 0.07584454300001653
# obtaine movies
# time: 1.1919051490000356
# calculate info
# time: 0.9345074699999714
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__editing__editor__1
# ['crew__editing__editor__1_avg_profit', 'crew__editing__editor__1_avg_revenue', 'crew__editing__editor__1_movies_before']
# time: 0.07574419900004159
# obtaine movies
# time: 1.1143304999999373
# calculate info
# time: 0.7763923659999818
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__costume__costume_designer
# ['crew__costume__costume_designer_avg_profit', 'crew__costume__costume_designer_avg_revenue', 'crew__costume__costume_designer_movies_before']
# time: 0.07404425199990783
# obtaine movies
# time: 0.28894404700008636
# calculate info
# time: 0.24717410499999914
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__costume__costume_supervisor
# ['crew__costume__costume_supervisor_avg_profit', 'crew__costume__costume_supervisor_avg_revenue', 'crew__costume__costume_supervisor_movies_before']
# time: 0.07410398399997575
# obtaine movies
# time: 0.3340164649999906
# calculate info
# time: 0.36855142000001706
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__costume__makeup_artist
# ['crew__costume__makeup_artist_avg_profit', 'crew__costume__makeup_artist_avg_revenue', 'crew__costume__makeup_artist_movies_before']
# time: 0.07450052499996218
# obtaine movies
# time: 0.34527726200008146
# calculate info
# time: 0.2998960580000585
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__crew__stunt_coordinator
# ['crew__crew__stunt_coordinator_avg_profit', 'crew__crew__stunt_coordinator_avg_revenue', 'crew__crew__stunt_coordinator_movies_before']
# time: 0.07802994700000454
# obtaine movies
# time: 0.6365794849999702
# calculate info
# time: 0.6965901269999222
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__writing__screenplay__1
# ['crew__writing__screenplay__1_avg_profit', 'crew__writing__screenplay__1_avg_revenue', 'crew__writing__screenplay__1_movies_before']
# time: 0.0764146049999681
# obtaine movies
# time: 0.5407505800000081
# calculate info
# time: 0.6454920529999981
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__art_direction
# ['crew__art__art_direction_avg_profit', 'crew__art__art_direction_avg_revenue', 'crew__art__art_direction_movies_before']
# time: 0.07662711800003308
# obtaine movies
# time: 1.1070758959999694
# calculate info
# time: 0.8622630620000109
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__production_design
# ['crew__art__production_design_avg_profit', 'crew__art__production_design_avg_revenue', 'crew__art__production_design_movies_before']
# time: 0.0768261609999854
# obtaine movies
# time: 0.34379270600004475
# calculate info
# time: 0.293412539999963
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__property_master
# ['crew__art__property_master_avg_profit', 'crew__art__property_master_avg_revenue', 'crew__art__property_master_movies_before']
# time: 0.07384340299995529
# obtaine movies
# time: 0.650605546999941
# calculate info
# time: 0.5577279489999682
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__set_decoration
# ['crew__art__set_decoration_avg_profit', 'crew__art__set_decoration_avg_revenue', 'crew__art__set_decoration_movies_before']
# time: 0.07563863899997614
# obtaine movies
# time: 0.3267717520000133
# calculate info
# time: 0.2981688429999849
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__visualeffects__visual_effects_supervisor
# ['crew__visualeffects__visual_effects_supervisor_avg_profit', 'crew__visualeffects__visual_effects_supervisor_avg_revenue', 'crew__visualeffects__visual_effects_supervisor_movies_before']
# time: 0.07376222400000643
# obtaine movies
# time: 1.3468764010000314
# calculate info
# time: 0.9896537759999546
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__camera__director_of_photography
# ['crew__camera__director_of_photography_avg_profit', 'crew__camera__director_of_photography_avg_revenue', 'crew__camera__director_of_photography_movies_before']
# time: 0.07644182799992905
# obtaine movies
# time: 0.3049047700000074
# calculate info
# time: 0.23313993800002208
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__camera__steadicam_operator
# ['crew__camera__steadicam_operator_avg_profit', 'crew__camera__steadicam_operator_avg_revenue', 'crew__camera__steadicam_operator_movies_before']
# time: 0.07538672900000165
# obtaine movies
# time: 0.6289676070000496
# calculate info
# time: 0.4534574240000211
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__camera__still_photographer
# ['crew__camera__still_photographer_avg_profit', 'crew__camera__still_photographer_avg_revenue', 'crew__camera__still_photographer_movies_before']
# time: 0.0764212359999874
# obtaine movies
# time: 0.27994054099997356
# calculate info
# time: 0.19329232400002638
# get columns
# ['avg_profit', 'avg_revenue']
# META__collection_name
# ['collection_avg_profit', 'collection_avg_revenue']
# time: 0.07957626100005655
# overall time: 58.498713943999974
# ------------------------------------------------------
# years2000-2018
# -------------------------------------------------------
# obtaine movies
# time: 21.11682178700005
# calculate info
# time: 22.429510219999997
# get columns
# ['avg_profit', 'avg_revenue']
# META__production_company_1
# ['production_company_1_avg_profit', 'production_company_1_avg_revenue']
# META__production_company_2
# ['production_company_2_avg_profit', 'production_company_2_avg_revenue']
# META__production_company_3
# ['production_company_3_avg_profit', 'production_company_3_avg_revenue']
# time: 1.2652461039999707
# obtaine movies
# time: 66.03429761200005
# calculate info
# time: 51.159765064
# get columns
# ['avg_profit', 'experience', 'avg_revenue', 'movies_before']
# META__cast_1_name
# ['cast_1_avg_profit', 'cast_1_experience', 'cast_1_avg_revenue', 'cast_1_movies_before']
# META__cast_2_name
# ['cast_2_avg_profit', 'cast_2_experience', 'cast_2_avg_revenue', 'cast_2_movies_before']
# META__cast_3_name
# ['cast_3_avg_profit', 'cast_3_experience', 'cast_3_avg_revenue', 'cast_3_movies_before']
# META__cast_4_name
# ['cast_4_avg_profit', 'cast_4_experience', 'cast_4_avg_revenue', 'cast_4_movies_before']
# META__cast_5_name
# ['cast_5_avg_profit', 'cast_5_experience', 'cast_5_avg_revenue', 'cast_5_movies_before']
# META__cast_6_name
# ['cast_6_avg_profit', 'cast_6_experience', 'cast_6_avg_revenue', 'cast_6_movies_before']
# META__cast_7_name
# ['cast_7_avg_profit', 'cast_7_experience', 'cast_7_avg_revenue', 'cast_7_movies_before']
# META__cast_8_name
# ['cast_8_avg_profit', 'cast_8_experience', 'cast_8_avg_revenue', 'cast_8_movies_before']
# time: 3.4892430859999877
# obtaine movies
# time: 2.864511888000038
# calculate info
# time: 1.74918707300003
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__music_editor
# ['crew__sound__music_editor_avg_profit', 'crew__sound__music_editor_avg_revenue', 'crew__sound__music_editor_movies_before']
# time: 0.43055192400004216
# obtaine movies
# time: 6.193439079999962
# calculate info
# time: 4.798392448999948
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__original_music_composer
# ['crew__sound__original_music_composer_avg_profit', 'crew__sound__original_music_composer_avg_revenue', 'crew__sound__original_music_composer_movies_before']
# time: 0.4405194130000609
# obtaine movies
# time: 2.201822072000027
# calculate info
# time: 1.4978841870000679
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__sound_designer
# ['crew__sound__sound_designer_avg_profit', 'crew__sound__sound_designer_avg_revenue', 'crew__sound__sound_designer_movies_before']
# time: 0.43608795700004066
# obtaine movies
# time: 2.2937407570000232
# calculate info
# time: 1.5329649399999425
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__sound_effects_editor
# ['crew__sound__sound_effects_editor_avg_profit', 'crew__sound__sound_effects_editor_avg_revenue', 'crew__sound__sound_effects_editor_movies_before']
# time: 0.43327578699995684
# obtaine movies
# time: 3.2557769980001012
# calculate info
# time: 2.119736020000005
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__sound_re_recording_mixer
# ['crew__sound__sound_re_recording_mixer_avg_profit', 'crew__sound__sound_re_recording_mixer_avg_revenue', 'crew__sound__sound_re_recording_mixer_movies_before']
# time: 0.42887226599998485
# obtaine movies
# time: 2.950684682999963
# calculate info
# time: 1.8746830840000257
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__supervising_sound_editor
# ['crew__sound__supervising_sound_editor_avg_profit', 'crew__sound__supervising_sound_editor_avg_revenue', 'crew__sound__supervising_sound_editor_movies_before']
# time: 0.42946020300007604
# obtaine movies
# time: 6.766060158999949
# calculate info
# time: 5.823688620999974
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__directing__director__1
# ['crew__directing__director__1_avg_profit', 'crew__directing__director__1_avg_revenue', 'crew__directing__director__1_movies_before']
# time: 0.4294773809999697
# obtaine movies
# time: 3.5379795150000746
# calculate info
# time: 2.4022029940000493
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__directing__script_supervisor
# ['crew__directing__script_supervisor_avg_profit', 'crew__directing__script_supervisor_avg_revenue', 'crew__directing__script_supervisor_movies_before']
# time: 0.43935918900001525
# obtaine movies
# time: 6.6865602469999885
# calculate info
# time: 5.732292471000051
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__casting
# ['crew__production__casting_avg_profit', 'crew__production__casting_avg_revenue', 'crew__production__casting_movies_before']
# time: 0.4363143420000597
# obtaine movies
# time: 3.9998577400000386
# calculate info
# time: 3.873432906000062
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__executive_producer__1
# ['crew__production__executive_producer__1_avg_profit', 'crew__production__executive_producer__1_avg_revenue', 'crew__production__executive_producer__1_movies_before']
# time: 0.4350360600000158
# obtaine movies
# time: 6.696866295999939
# calculate info
# time: 5.376872485000035
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__producer__1
# ['crew__production__producer__1_avg_profit', 'crew__production__producer__1_avg_revenue', 'crew__production__producer__1_movies_before']
# time: 0.42377239999996164
# obtaine movies
# time: 2.2640683260000287
# calculate info
# time: 2.461375493999981
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__producer__2
# ['crew__production__producer__2_avg_profit', 'crew__production__producer__2_avg_revenue', 'crew__production__producer__2_movies_before']
# time: 0.41869741200002863
# obtaine movies
# time: 7.178061446000015
# calculate info
# time: 5.072304660999976
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__editing__editor__1
# ['crew__editing__editor__1_avg_profit', 'crew__editing__editor__1_avg_revenue', 'crew__editing__editor__1_movies_before']
# time: 0.4188310399999864
# obtaine movies
# time: 5.6573480490000065
# calculate info
# time: 4.02441477900004
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__costume__costume_designer
# ['crew__costume__costume_designer_avg_profit', 'crew__costume__costume_designer_avg_revenue', 'crew__costume__costume_designer_movies_before']
# time: 0.429802149000011
# obtaine movies
# time: 1.8686647460000358
# calculate info
# time: 1.3593424890000279
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__costume__costume_supervisor
# ['crew__costume__costume_supervisor_avg_profit', 'crew__costume__costume_supervisor_avg_revenue', 'crew__costume__costume_supervisor_movies_before']
# time: 0.418148221000024
# obtaine movies
# time: 1.7631808930000261
# calculate info
# time: 1.6070036219999793
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__costume__makeup_artist
# ['crew__costume__makeup_artist_avg_profit', 'crew__costume__makeup_artist_avg_revenue', 'crew__costume__makeup_artist_movies_before']
# time: 0.43241178599998875
# obtaine movies
# time: 2.381427271000007
# calculate info
# time: 1.6204938299999867
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__crew__stunt_coordinator
# ['crew__crew__stunt_coordinator_avg_profit', 'crew__crew__stunt_coordinator_avg_revenue', 'crew__crew__stunt_coordinator_movies_before']
# time: 0.42202549700004965
# obtaine movies
# time: 3.2697085710000238
# calculate info
# time: 3.222805376999986
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__writing__screenplay__1
# ['crew__writing__screenplay__1_avg_profit', 'crew__writing__screenplay__1_avg_revenue', 'crew__writing__screenplay__1_movies_before']
# time: 0.42595721500003947
# obtaine movies
# time: 3.595846196000025
# calculate info
# time: 3.0273743740000327
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__art_direction
# ['crew__art__art_direction_avg_profit', 'crew__art__art_direction_avg_revenue', 'crew__art__art_direction_movies_before']
# time: 0.4200384009999425
# obtaine movies
# time: 5.952394040000058
# calculate info
# time: 4.176975784999968
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__production_design
# ['crew__art__production_design_avg_profit', 'crew__art__production_design_avg_revenue', 'crew__art__production_design_movies_before']
# time: 0.4304501630000459
# obtaine movies
# time: 2.0624278139999888
# calculate info
# time: 1.4562996250000424
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__property_master
# ['crew__art__property_master_avg_profit', 'crew__art__property_master_avg_revenue', 'crew__art__property_master_movies_before']
# time: 0.4246788560000141
# obtaine movies
# time: 4.172572781999975
# calculate info
# time: 2.941913815000021
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__set_decoration
# ['crew__art__set_decoration_avg_profit', 'crew__art__set_decoration_avg_revenue', 'crew__art__set_decoration_movies_before']
# time: 0.4309707999999546
# obtaine movies
# time: 2.193933916999981
# calculate info
# time: 1.7253668520000929
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__visualeffects__visual_effects_supervisor
# ['crew__visualeffects__visual_effects_supervisor_avg_profit', 'crew__visualeffects__visual_effects_supervisor_avg_revenue', 'crew__visualeffects__visual_effects_supervisor_movies_before']
# time: 0.4270577270000331
# obtaine movies
# time: 7.2383719010000505
# calculate info
# time: 5.153937373000076
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__camera__director_of_photography
# ['crew__camera__director_of_photography_avg_profit', 'crew__camera__director_of_photography_avg_revenue', 'crew__camera__director_of_photography_movies_before']
# time: 0.43554818199993406
# obtaine movies
# time: 1.9113429970000197
# calculate info
# time: 1.2063050199999452
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__camera__steadicam_operator
# ['crew__camera__steadicam_operator_avg_profit', 'crew__camera__steadicam_operator_avg_revenue', 'crew__camera__steadicam_operator_movies_before']
# time: 0.4289160590000165
# obtaine movies
# time: 3.235749726999984
# calculate info
# time: 2.158503257999996
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__camera__still_photographer
# ['crew__camera__still_photographer_avg_profit', 'crew__camera__still_photographer_avg_revenue', 'crew__camera__still_photographer_movies_before']
# time: 0.43268233699996017
# obtaine movies
# time: 1.3147458600000164
# calculate info
# time: 0.8844581469999184
# get columns
# ['avg_profit', 'avg_revenue']
# META__collection_name
# ['collection_avg_profit', 'collection_avg_revenue']
# time: 0.4322790219999888
# overall time: 363.34616839
# ------------------------------------------------------
# years1970-1999
# -------------------------------------------------------
# obtaine movies
# time: 7.53052956199997
# calculate info
# time: 9.567833566000104
# get columns
# ['avg_profit', 'avg_revenue']
# META__production_company_1
# ['production_company_1_avg_profit', 'production_company_1_avg_revenue']
# META__production_company_2
# ['production_company_2_avg_profit', 'production_company_2_avg_revenue']
# META__production_company_3
# ['production_company_3_avg_profit', 'production_company_3_avg_revenue']
# time: 0.5114919320000126
# obtaine movies
# time: 24.417601856000033
# calculate info
# time: 20.324656990999983
# get columns
# ['avg_profit', 'experience', 'avg_revenue', 'movies_before']
# META__cast_1_name
# ['cast_1_avg_profit', 'cast_1_experience', 'cast_1_avg_revenue', 'cast_1_movies_before']
# META__cast_2_name
# ['cast_2_avg_profit', 'cast_2_experience', 'cast_2_avg_revenue', 'cast_2_movies_before']
# META__cast_3_name
# ['cast_3_avg_profit', 'cast_3_experience', 'cast_3_avg_revenue', 'cast_3_movies_before']
# META__cast_4_name
# ['cast_4_avg_profit', 'cast_4_experience', 'cast_4_avg_revenue', 'cast_4_movies_before']
# META__cast_5_name
# ['cast_5_avg_profit', 'cast_5_experience', 'cast_5_avg_revenue', 'cast_5_movies_before']
# META__cast_6_name
# ['cast_6_avg_profit', 'cast_6_experience', 'cast_6_avg_revenue', 'cast_6_movies_before']
# META__cast_7_name
# ['cast_7_avg_profit', 'cast_7_experience', 'cast_7_avg_revenue', 'cast_7_movies_before']
# META__cast_8_name
# ['cast_8_avg_profit', 'cast_8_experience', 'cast_8_avg_revenue', 'cast_8_movies_before']
# time: 1.3731274540000413
# obtaine movies
# time: 0.8491391850000127
# calculate info
# time: 0.4651067629999943
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__music_editor
# ['crew__sound__music_editor_avg_profit', 'crew__sound__music_editor_avg_revenue', 'crew__sound__music_editor_movies_before']
# time: 0.16544225999996343
# obtaine movies
# time: 3.412346556999978
# calculate info
# time: 2.1569224239999585
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__original_music_composer
# ['crew__sound__original_music_composer_avg_profit', 'crew__sound__original_music_composer_avg_revenue', 'crew__sound__original_music_composer_movies_before']
# time: 0.17019848899997214
# obtaine movies
# time: 0.42530295400001705
# calculate info
# time: 0.23692672599997877
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__sound_designer
# ['crew__sound__sound_designer_avg_profit', 'crew__sound__sound_designer_avg_revenue', 'crew__sound__sound_designer_movies_before']
# time: 0.17248750300007032
# obtaine movies
# time: 0.45256248499993035
# calculate info
# time: 0.3121480549998523
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__sound_effects_editor
# ['crew__sound__sound_effects_editor_avg_profit', 'crew__sound__sound_effects_editor_avg_revenue', 'crew__sound__sound_effects_editor_movies_before']
# time: 0.16677074000017456
# obtaine movies
# time: 0.9928324350000821
# calculate info
# time: 0.5450162449999425
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__sound_re_recording_mixer
# ['crew__sound__sound_re_recording_mixer_avg_profit', 'crew__sound__sound_re_recording_mixer_avg_revenue', 'crew__sound__sound_re_recording_mixer_movies_before']
# time: 0.1677867729999889
# obtaine movies
# time: 0.9530656110000564
# calculate info
# time: 0.5417206360000364
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__supervising_sound_editor
# ['crew__sound__supervising_sound_editor_avg_profit', 'crew__sound__supervising_sound_editor_avg_revenue', 'crew__sound__supervising_sound_editor_movies_before']
# time: 0.1700469580000572
# obtaine movies
# time: 3.7206015599999773
# calculate info
# time: 2.491141088999939
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__directing__director__1
# ['crew__directing__director__1_avg_profit', 'crew__directing__director__1_avg_revenue', 'crew__directing__director__1_movies_before']
# time: 0.1742108379999081
# obtaine movies
# time: 1.1914973729999474
# calculate info
# time: 0.7311652999999296
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__directing__script_supervisor
# ['crew__directing__script_supervisor_avg_profit', 'crew__directing__script_supervisor_avg_revenue', 'crew__directing__script_supervisor_movies_before']
# time: 0.1678203310000299
# obtaine movies
# time: 2.935201544999927
# calculate info
# time: 1.6624925030000668
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__casting
# ['crew__production__casting_avg_profit', 'crew__production__casting_avg_revenue', 'crew__production__casting_movies_before']
# time: 0.16893766600014715
# obtaine movies
# time: 1.5347392849998869
# calculate info
# time: 1.2805857869998363
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__executive_producer__1
# ['crew__production__executive_producer__1_avg_profit', 'crew__production__executive_producer__1_avg_revenue', 'crew__production__executive_producer__1_movies_before']
# time: 0.16848767299984502
# obtaine movies
# time: 3.038208665999946
# calculate info
# time: 2.2241494279999188
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__producer__1
# ['crew__production__producer__1_avg_profit', 'crew__production__producer__1_avg_revenue', 'crew__production__producer__1_movies_before']
# time: 0.17470335399980286
# obtaine movies
# time: 0.3811221910000313
# calculate info
# time: 0.4395766370000729
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__producer__2
# ['crew__production__producer__2_avg_profit', 'crew__production__producer__2_avg_revenue', 'crew__production__producer__2_movies_before']
# time: 0.17237684299993816
# obtaine movies
# time: 3.862643779000109
# calculate info
# time: 2.3188307670000086
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__editing__editor__1
# ['crew__editing__editor__1_avg_profit', 'crew__editing__editor__1_avg_revenue', 'crew__editing__editor__1_movies_before']
# time: 0.17852091500003553
# obtaine movies
# time: 2.4669383399998424
# calculate info
# time: 1.4832014010000876
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__costume__costume_designer
# ['crew__costume__costume_designer_avg_profit', 'crew__costume__costume_designer_avg_revenue', 'crew__costume__costume_designer_movies_before']
# time: 0.176701082000136
# obtaine movies
# time: 0.4994870499999706
# calculate info
# time: 0.3232860189998519
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__costume__costume_supervisor
# ['crew__costume__costume_supervisor_avg_profit', 'crew__costume__costume_supervisor_avg_revenue', 'crew__costume__costume_supervisor_movies_before']
# time: 0.16847261300017635
# obtaine movies
# time: 1.1034259570001268
# calculate info
# time: 0.7995680989999983
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__costume__makeup_artist
# ['crew__costume__makeup_artist_avg_profit', 'crew__costume__makeup_artist_avg_revenue', 'crew__costume__makeup_artist_movies_before']
# time: 0.17254603199990015
# obtaine movies
# time: 0.8880695289999494
# calculate info
# time: 0.5409905860001345
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__crew__stunt_coordinator
# ['crew__crew__stunt_coordinator_avg_profit', 'crew__crew__stunt_coordinator_avg_revenue', 'crew__crew__stunt_coordinator_movies_before']
# time: 0.17035785600000963
# obtaine movies
# time: 2.0395460600000206
# calculate info
# time: 1.681754999000077
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__writing__screenplay__1
# ['crew__writing__screenplay__1_avg_profit', 'crew__writing__screenplay__1_avg_revenue', 'crew__writing__screenplay__1_movies_before']
# time: 0.17263411399994766
# obtaine movies
# time: 1.5515542719999758
# calculate info
# time: 1.2336634719999893
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__art_direction
# ['crew__art__art_direction_avg_profit', 'crew__art__art_direction_avg_revenue', 'crew__art__art_direction_movies_before']
# time: 0.17151200800003608
# obtaine movies
# time: 2.7414187230001517
# calculate info
# time: 1.6189473489998818
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__production_design
# ['crew__art__production_design_avg_profit', 'crew__art__production_design_avg_revenue', 'crew__art__production_design_movies_before']
# time: 0.17306958000017403
# obtaine movies
# time: 0.7856606309999279
# calculate info
# time: 0.5130591189999905
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__property_master
# ['crew__art__property_master_avg_profit', 'crew__art__property_master_avg_revenue', 'crew__art__property_master_movies_before']
# time: 0.1712045730000682
# obtaine movies
# time: 2.046762637000029
# calculate info
# time: 1.2609602210000048
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__set_decoration
# ['crew__art__set_decoration_avg_profit', 'crew__art__set_decoration_avg_revenue', 'crew__art__set_decoration_movies_before']
# time: 0.17206618900013382
# obtaine movies
# time: 0.4165064540000003
# calculate info
# time: 0.24610097199979464
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__visualeffects__visual_effects_supervisor
# ['crew__visualeffects__visual_effects_supervisor_avg_profit', 'crew__visualeffects__visual_effects_supervisor_avg_revenue', 'crew__visualeffects__visual_effects_supervisor_movies_before']
# time: 0.17604218799988303
# obtaine movies
# time: 4.104977660000031
# calculate info
# time: 2.3675246579998657
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__camera__director_of_photography
# ['crew__camera__director_of_photography_avg_profit', 'crew__camera__director_of_photography_avg_revenue', 'crew__camera__director_of_photography_movies_before']
# time: 0.1752874650001104
# obtaine movies
# time: 0.5638446959999328
# calculate info
# time: 0.26462168100010786
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__camera__steadicam_operator
# ['crew__camera__steadicam_operator_avg_profit', 'crew__camera__steadicam_operator_avg_revenue', 'crew__camera__steadicam_operator_movies_before']
# time: 0.17399131000001944
# obtaine movies
# time: 1.1827769189999344
# calculate info
# time: 0.6745491149999907
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__camera__still_photographer
# ['crew__camera__still_photographer_avg_profit', 'crew__camera__still_photographer_avg_revenue', 'crew__camera__still_photographer_movies_before']
# time: 0.180329724999865
# obtaine movies
# time: 0.7956555360001403
# calculate info
# time: 0.4840495710000141
# get columns
# ['avg_profit', 'avg_revenue']
# META__collection_name
# ['collection_avg_profit', 'collection_avg_revenue']
# time: 0.178299177000099
# overall time: 143.85297222400004
# ------------------------------------------------------
# profitability_positive
# -------------------------------------------------------
# obtaine movies
# time: 21.699428030000036
# calculate info
# time: 29.76952135500005
# get columns
# ['avg_profit', 'avg_revenue']
# META__production_company_1
# ['production_company_1_avg_profit', 'production_company_1_avg_revenue']
# META__production_company_2
# ['production_company_2_avg_profit', 'production_company_2_avg_revenue']
# META__production_company_3
# ['production_company_3_avg_profit', 'production_company_3_avg_revenue']
# time: 1.277882763999969
# obtaine movies
# time: 65.39851700100007
# calculate info
# time: 52.452097912
# get columns
# ['avg_profit', 'experience', 'avg_revenue', 'movies_before']
# META__cast_1_name
# ['cast_1_avg_profit', 'cast_1_experience', 'cast_1_avg_revenue', 'cast_1_movies_before']
# META__cast_2_name
# ['cast_2_avg_profit', 'cast_2_experience', 'cast_2_avg_revenue', 'cast_2_movies_before']
# META__cast_3_name
# ['cast_3_avg_profit', 'cast_3_experience', 'cast_3_avg_revenue', 'cast_3_movies_before']
# META__cast_4_name
# ['cast_4_avg_profit', 'cast_4_experience', 'cast_4_avg_revenue', 'cast_4_movies_before']
# META__cast_5_name
# ['cast_5_avg_profit', 'cast_5_experience', 'cast_5_avg_revenue', 'cast_5_movies_before']
# META__cast_6_name
# ['cast_6_avg_profit', 'cast_6_experience', 'cast_6_avg_revenue', 'cast_6_movies_before']
# META__cast_7_name
# ['cast_7_avg_profit', 'cast_7_experience', 'cast_7_avg_revenue', 'cast_7_movies_before']
# META__cast_8_name
# ['cast_8_avg_profit', 'cast_8_experience', 'cast_8_avg_revenue', 'cast_8_movies_before']
# time: 3.5639527050000197
# obtaine movies
# time: 2.8141207129999657
# calculate info
# time: 1.742762108000079
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__music_editor
# ['crew__sound__music_editor_avg_profit', 'crew__sound__music_editor_avg_revenue', 'crew__sound__music_editor_movies_before']
# time: 0.4446522079999795
# obtaine movies
# time: 7.098431185999971
# calculate info
# time: 5.580114111000057
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__original_music_composer
# ['crew__sound__original_music_composer_avg_profit', 'crew__sound__original_music_composer_avg_revenue', 'crew__sound__original_music_composer_movies_before']
# time: 0.44242432600003667
# obtaine movies
# time: 2.0483089709998694
# calculate info
# time: 1.4140189489999102
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__sound_designer
# ['crew__sound__sound_designer_avg_profit', 'crew__sound__sound_designer_avg_revenue', 'crew__sound__sound_designer_movies_before']
# time: 0.4299299609999707
# obtaine movies
# time: 2.059191391000013
# calculate info
# time: 1.4229369489999044
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__sound_effects_editor
# ['crew__sound__sound_effects_editor_avg_profit', 'crew__sound__sound_effects_editor_avg_revenue', 'crew__sound__sound_effects_editor_movies_before']
# time: 0.4368914379999751
# obtaine movies
# time: 3.1105991710001035
# calculate info
# time: 2.0596483910001098
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__sound_re_recording_mixer
# ['crew__sound__sound_re_recording_mixer_avg_profit', 'crew__sound__sound_re_recording_mixer_avg_revenue', 'crew__sound__sound_re_recording_mixer_movies_before']
# time: 0.4380144819999714
# obtaine movies
# time: 2.904958949000047
# calculate info
# time: 1.9093382179999026
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__supervising_sound_editor
# ['crew__sound__supervising_sound_editor_avg_profit', 'crew__sound__supervising_sound_editor_avg_revenue', 'crew__sound__supervising_sound_editor_movies_before']
# time: 0.4408325379999951
# obtaine movies
# time: 7.603095903999929
# calculate info
# time: 6.068834711999898
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__directing__director__1
# ['crew__directing__director__1_avg_profit', 'crew__directing__director__1_avg_revenue', 'crew__directing__director__1_movies_before']
# time: 0.4478968620001069
# obtaine movies
# time: 3.377324205999912
# calculate info
# time: 2.3310114569999314
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__directing__script_supervisor
# ['crew__directing__script_supervisor_avg_profit', 'crew__directing__script_supervisor_avg_revenue', 'crew__directing__script_supervisor_movies_before']
# time: 0.4372016889999486
# obtaine movies
# time: 6.488709728999993
# calculate info
# time: 5.057995827000013
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__casting
# ['crew__production__casting_avg_profit', 'crew__production__casting_avg_revenue', 'crew__production__casting_movies_before']
# time: 0.43733936800003903
# obtaine movies
# time: 3.9262015760000395
# calculate info
# time: 3.7174986390000413
# get columns
# ...
# time: 0.44514817300023424
# obtaine movies
# time: 7.629409202999341
# calculate info
# time: 5.343066407999686
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__editing__editor__1
# ['crew__editing__editor__1_avg_profit', 'crew__editing__editor__1_avg_revenue', 'crew__editing__editor__1_movies_before']
# time: 0.44124150700008613
# obtaine movies
# time: 6.030862616000377
# calculate info
# time: 4.213552408999931
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__costume__costume_designer
# ['crew__costume__costume_designer_avg_profit', 'crew__costume__costume_designer_avg_revenue', 'crew__costume__costume_designer_movies_before']
# time: 0.44346508300077403
# obtaine movies
# time: 1.99059521900017
# calculate info
# time: 1.449239784999918
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__costume__costume_supervisor
# ['crew__costume__costume_supervisor_avg_profit', 'crew__costume__costume_supervisor_avg_revenue', 'crew__costume__costume_supervisor_movies_before']
# time: 0.4375411239998357
# obtaine movies
# time: 1.8627814439996655
# calculate info
# time: 1.6743054959997608
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__costume__makeup_artist
# ['crew__costume__makeup_artist_avg_profit', 'crew__costume__makeup_artist_avg_revenue', 'crew__costume__makeup_artist_movies_before']
# time: 0.43128399299985176
# obtaine movies
# time: 2.48155676100032
# calculate info
# time: 1.7075540499999988
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__crew__stunt_coordinator
# ['crew__crew__stunt_coordinator_avg_profit', 'crew__crew__stunt_coordinator_avg_revenue', 'crew__crew__stunt_coordinator_movies_before']
# time: 0.4449998489999416
# obtaine movies
# time: 3.358468514999913
# calculate info
# time: 3.3143130739999833
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__writing__screenplay__1
# ['crew__writing__screenplay__1_avg_profit', 'crew__writing__screenplay__1_avg_revenue', 'crew__writing__screenplay__1_movies_before']
# time: 0.4289547529997435
# obtaine movies
# time: 3.6903741719997925
# calculate info
# time: 3.1232678159994975
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__art_direction
# ['crew__art__art_direction_avg_profit', 'crew__art__art_direction_avg_revenue', 'crew__art__art_direction_movies_before']
# time: 0.43891849999999977
# obtaine movies
# time: 6.321818033000454
# calculate info
# time: 4.376290897000217
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__production_design
# ['crew__art__production_design_avg_profit', 'crew__art__production_design_avg_revenue', 'crew__art__production_design_movies_before']
# time: 0.4427559519999704
# obtaine movies
# time: 2.224178132999441
# calculate info
# time: 1.5190394880000895
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__property_master
# ['crew__art__property_master_avg_profit', 'crew__art__property_master_avg_revenue', 'crew__art__property_master_movies_before']
# time: 0.4427306019997559
# obtaine movies
# time: 4.381061688000045
# calculate info
# time: 3.0882852679997086
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__set_decoration
# ['crew__art__set_decoration_avg_profit', 'crew__art__set_decoration_avg_revenue', 'crew__art__set_decoration_movies_before']
# time: 0.443382601999474
# obtaine movies
# time: 2.3251964109995242
# calculate info
# time: 1.824969420999878
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__visualeffects__visual_effects_supervisor
# ['crew__visualeffects__visual_effects_supervisor_avg_profit', 'crew__visualeffects__visual_effects_supervisor_avg_revenue', 'crew__visualeffects__visual_effects_supervisor_movies_before']
# time: 0.4363951450004606
# obtaine movies
# time: 7.574750473000677
# calculate info
# time: 5.370980514000621
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__camera__director_of_photography
# ['crew__camera__director_of_photography_avg_profit', 'crew__camera__director_of_photography_avg_revenue', 'crew__camera__director_of_photography_movies_before']
# time: 0.453537415000028
# obtaine movies
# time: 2.029167261999646
# calculate info
# time: 1.2569400160000441
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__camera__steadicam_operator
# ['crew__camera__steadicam_operator_avg_profit', 'crew__camera__steadicam_operator_avg_revenue', 'crew__camera__steadicam_operator_movies_before']
# time: 0.42502780300037557
# obtaine movies
# time: 3.2942848909997338
# calculate info
# time: 2.1817450109992933
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__camera__still_photographer
# ['crew__camera__still_photographer_avg_profit', 'crew__camera__still_photographer_avg_revenue', 'crew__camera__still_photographer_movies_before']
# time: 0.43745210300039616
# obtaine movies
# time: 1.3736820060003083
# calculate info
# time: 0.8969602659999509
# get columns
# ['avg_profit', 'avg_revenue']
# META__collection_name
# ['collection_avg_profit', 'collection_avg_revenue']
# time: 0.42330214499997965
# overall time: 365.3969598039994
# ------------------------------------------------------
# profitability_1percentile_years2000-2018_budget_start_5percent
# -------------------------------------------------------
# obtaine movies
# time: 20.84769562600013
# calculate info
# time: 21.89114094499928
# get columns
# ['avg_profit', 'avg_revenue']
# META__production_company_1
# ['production_company_1_avg_profit', 'production_company_1_avg_revenue']
# META__production_company_2
# ['production_company_2_avg_profit', 'production_company_2_avg_revenue']
# META__production_company_3
# ['production_company_3_avg_profit', 'production_company_3_avg_revenue']
# time: 1.2370052220003345
# obtaine movies
# time: 65.17334975799986
# calculate info
# time: 48.5679927479996
# get columns
# ['avg_profit', 'experience', 'avg_revenue', 'movies_before']
# META__cast_1_name
# ['cast_1_avg_profit', 'cast_1_experience', 'cast_1_avg_revenue', 'cast_1_movies_before']
# META__cast_2_name
# ['cast_2_avg_profit', 'cast_2_experience', 'cast_2_avg_revenue', 'cast_2_movies_before']
# META__cast_3_name
# ['cast_3_avg_profit', 'cast_3_experience', 'cast_3_avg_revenue', 'cast_3_movies_before']
# META__cast_4_name
# ['cast_4_avg_profit', 'cast_4_experience', 'cast_4_avg_revenue', 'cast_4_movies_before']
# META__cast_5_name
# ['cast_5_avg_profit', 'cast_5_experience', 'cast_5_avg_revenue', 'cast_5_movies_before']
# META__cast_6_name
# ['cast_6_avg_profit', 'cast_6_experience', 'cast_6_avg_revenue', 'cast_6_movies_before']
# META__cast_7_name
# ['cast_7_avg_profit', 'cast_7_experience', 'cast_7_avg_revenue', 'cast_7_movies_before']
# META__cast_8_name
# ['cast_8_avg_profit', 'cast_8_experience', 'cast_8_avg_revenue', 'cast_8_movies_before']
# time: 3.27200026599985
# obtaine movies
# time: 2.7744419059999927
# calculate info
# time: 1.6890675800004828
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__music_editor
# ['crew__sound__music_editor_avg_profit', 'crew__sound__music_editor_avg_revenue', 'crew__sound__music_editor_movies_before']
# time: 0.3997643180000523
# obtaine movies
# time: 6.070334316000299
# calculate info
# time: 4.571140406000268
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__original_music_composer
# ['crew__sound__original_music_composer_avg_profit', 'crew__sound__original_music_composer_avg_revenue', 'crew__sound__original_music_composer_movies_before']
# time: 0.39379682500020863
# obtaine movies
# time: 2.1749161920006372
# calculate info
# time: 1.455781167999703
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__sound_designer
# ['crew__sound__sound_designer_avg_profit', 'crew__sound__sound_designer_avg_revenue', 'crew__sound__sound_designer_movies_before']
# time: 0.3936834119995183
# obtaine movies
# time: 2.2016285159998006
# calculate info
# time: 1.5046943110000939
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__sound_effects_editor
# ['crew__sound__sound_effects_editor_avg_profit', 'crew__sound__sound_effects_editor_avg_revenue', 'crew__sound__sound_effects_editor_movies_before']
# time: 0.403815303000556
# obtaine movies
# time: 3.1771673560006093
# calculate info
# time: 2.107066821000444
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__sound_re_recording_mixer
# ['crew__sound__sound_re_recording_mixer_avg_profit', 'crew__sound__sound_re_recording_mixer_avg_revenue', 'crew__sound__sound_re_recording_mixer_movies_before']
# time: 0.4106826359993647
# obtaine movies
# time: 2.8472238939993986
# calculate info
# time: 1.857984208999369
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__sound__supervising_sound_editor
# ['crew__sound__supervising_sound_editor_avg_profit', 'crew__sound__supervising_sound_editor_avg_revenue', 'crew__sound__supervising_sound_editor_movies_before']
# time: 0.4064281699993444
# obtaine movies
# time: 6.656088781999642
# calculate info
# time: 5.606552301999727
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__directing__director__1
# ['crew__directing__director__1_avg_profit', 'crew__directing__director__1_avg_revenue', 'crew__directing__director__1_movies_before']
# time: 0.415901259999373
# obtaine movies
# time: 3.567584254999929
# calculate info
# time: 2.4134653410001192
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__directing__script_supervisor
# ['crew__directing__script_supervisor_avg_profit', 'crew__directing__script_supervisor_avg_revenue', 'crew__directing__script_supervisor_movies_before']
# time: 0.418686715000149
# obtaine movies
# time: 6.718065091000426
# calculate info
# time: 5.650296687000264
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__casting
# ['crew__production__casting_avg_profit', 'crew__production__casting_avg_revenue', 'crew__production__casting_movies_before']
# time: 0.41446606800036534
# obtaine movies
# time: 3.924412093999308
# calculate info
# time: 3.681738850000329
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__executive_producer__1
# ['crew__production__executive_producer__1_avg_profit', 'crew__production__executive_producer__1_avg_revenue', 'crew__production__executive_producer__1_movies_before']
# time: 0.40144719099953363
# obtaine movies
# time: 6.443847945999551
# calculate info
# time: 5.206501398999535
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__producer__1
# ['crew__production__producer__1_avg_profit', 'crew__production__producer__1_avg_revenue', 'crew__production__producer__1_movies_before']
# time: 0.4022769060002247
# obtaine movies
# time: 2.305117978999988
# calculate info
# time: 2.5085200479998093
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__production__producer__2
# ['crew__production__producer__2_avg_profit', 'crew__production__producer__2_avg_revenue', 'crew__production__producer__2_movies_before']
# time: 0.4103273689997877
# obtaine movies
# time: 7.407510955999896
# calculate info
# time: 5.221716976000607
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__editing__editor__1
# ['crew__editing__editor__1_avg_profit', 'crew__editing__editor__1_avg_revenue', 'crew__editing__editor__1_movies_before']
# time: 0.41903190200082463
# obtaine movies
# time: 6.001463784999942
# calculate info
# time: 4.106975042999693
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__costume__costume_designer
# ['crew__costume__costume_designer_avg_profit', 'crew__costume__costume_designer_avg_revenue', 'crew__costume__costume_designer_movies_before']
# time: 0.4137138630003392
# obtaine movies
# time: 1.9491250870005388
# calculate info
# time: 1.4153523479999421
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__costume__costume_supervisor
# ['crew__costume__costume_supervisor_avg_profit', 'crew__costume__costume_supervisor_avg_revenue', 'crew__costume__costume_supervisor_movies_before']
# time: 0.4220651289997477
# obtaine movies
# time: 1.8135234729998047
# calculate info
# time: 1.6587906939994355
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__costume__makeup_artist
# ['crew__costume__makeup_artist_avg_profit', 'crew__costume__makeup_artist_avg_revenue', 'crew__costume__makeup_artist_movies_before']
# time: 0.4124006450001616
# obtaine movies
# time: 2.4546493199995894
# calculate info
# time: 1.6803980569993655
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__crew__stunt_coordinator
# ['crew__crew__stunt_coordinator_avg_profit', 'crew__crew__stunt_coordinator_avg_revenue', 'crew__crew__stunt_coordinator_movies_before']
# time: 0.41336640999998053
# obtaine movies
# time: 3.3926902999992308
# calculate info
# time: 3.3710064510005395
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__writing__screenplay__1
# ['crew__writing__screenplay__1_avg_profit', 'crew__writing__screenplay__1_avg_revenue', 'crew__writing__screenplay__1_movies_before']
# time: 0.4282424050006739
# obtaine movies
# time: 3.782357768000111
# calculate info
# time: 3.1049861869996676
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__art_direction
# ['crew__art__art_direction_avg_profit', 'crew__art__art_direction_avg_revenue', 'crew__art__art_direction_movies_before']
# time: 0.4163702129999365
# obtaine movies
# time: 6.170645104999494
# calculate info
# time: 4.314179721999608
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__production_design
# ['crew__art__production_design_avg_profit', 'crew__art__production_design_avg_revenue', 'crew__art__production_design_movies_before']
# time: 0.41908953899928747
# obtaine movies
# time: 2.1876516870006526
# calculate info
# time: 1.5272827760009022
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__property_master
# ['crew__art__property_master_avg_profit', 'crew__art__property_master_avg_revenue', 'crew__art__property_master_movies_before']
# time: 0.4250172570000359
# obtaine movies
# time: 4.373035955999512
# calculate info
# time: 3.0619117539999934
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__art__set_decoration
# ['crew__art__set_decoration_avg_profit', 'crew__art__set_decoration_avg_revenue', 'crew__art__set_decoration_movies_before']
# time: 0.42428485399977944
# obtaine movies
# time: 2.3348196639999514
# calculate info
# time: 1.807422399000643
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__visualeffects__visual_effects_supervisor
# ['crew__visualeffects__visual_effects_supervisor_avg_profit', 'crew__visualeffects__visual_effects_supervisor_avg_revenue', 'crew__visualeffects__visual_effects_supervisor_movies_before']
# time: 0.4413604689998465
# obtaine movies
# time: 7.52432445499926
# calculate info
# time: 5.076369788000193
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__camera__director_of_photography
# ['crew__camera__director_of_photography_avg_profit', 'crew__camera__director_of_photography_avg_revenue', 'crew__camera__director_of_photography_movies_before']
# time: 0.41754018099982204
# obtaine movies
# time: 1.9386161659995196
# calculate info
# time: 1.2309827640001458
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__camera__steadicam_operator
# ['crew__camera__steadicam_operator_avg_profit', 'crew__camera__steadicam_operator_avg_revenue', 'crew__camera__steadicam_operator_movies_before']
# time: 0.40400366599988047
# obtaine movies
# time: 3.3190362830000595
# calculate info
# time: 2.1747218370001065
# get columns
# ['avg_profit', 'avg_revenue', 'movies_before']
# META__crew__camera__still_photographer
# ['crew__camera__still_photographer_avg_profit', 'crew__camera__still_photographer_avg_revenue', 'crew__camera__still_photographer_movies_before']
# time: 0.4113265649993991
# obtaine movies
# time: 1.3237033290006366
# calculate info
# time: 0.8923749810001027
# get columns
# ['avg_profit', 'avg_revenue']
# META__collection_name
# ['collection_avg_profit', 'collection_avg_revenue']
# time: 0.41498150799998257
# overall time: 359.7093497619999
